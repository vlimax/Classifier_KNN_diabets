# %%
#Manipulação de Dados
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#Aprendizado de Máquina
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

#Carregar e Preparar dados
def algoritmo_Knn(X_train, X_test, y_train, y_test, tipo_de_imputacao):
    # 2. Normalizar
    scaler = StandardScaler()
    X_train_scaled_Stand = scaler.fit_transform(X_train)
    X_test_scaled_Stand = scaler.transform(X_test)

    scaler = MinMaxScaler()
    X_train_scaled_Min = scaler.fit_transform(X_train)
    X_test_scaled_Min = scaler.transform(X_test)
    
    # 3. Treinar o KNN
    iterador = [2, 3, 4, 5, 6, 7, 8, 9]
    for vizinhos in iterador:
        knn_stand = KNeighborsClassifier(n_neighbors=vizinhos)
        knn_stand.fit(X_train_scaled_Stand, y_train)
        
        knn_min = KNeighborsClassifier(n_neighbors=vizinhos)
        knn_min.fit(X_train_scaled_Min, y_train)
        
        # 4. Fazer predições
        y_pred_scaled_Stand = knn_stand.predict(X_test_scaled_Stand)
        y_pred_scaled_Min = knn_min.predict(X_test_scaled_Min)
        
        # 5. Avaliar
        acuracia_Stand = knn_stand.score(X_test_scaled_Stand, y_test)
        acuracia_Min = knn_min.score(X_test_scaled_Min, y_test)
        
        print(f"Acurácia Dados Brutos com imputação por {tipo_de_imputacao}, StandartScaler: {acuracia_Stand:.3f} e {vizinhos} vizinho(s).")
        matriz_confusao = confusion_matrix(y_test, y_pred_scaled_Stand)
        sns.heatmap(matriz_confusao, annot=True, fmt='d', cmap='Blues', cbar=False)
        plt.xlabel('Previsto')
        plt.ylabel('Real')
        plt.title('Matriz de Confusão com SandardScaler')
        plt.show()

        print(f"Acurácia Dados Brutos com imputação por {tipo_de_imputacao}, MinMaxScaler: {acuracia_Min:.3f} e {vizinhos} vizinho(s).")
        matriz_confusao = confusion_matrix(y_test, y_pred_scaled_Min)
        sns.heatmap(matriz_confusao, annot=True, fmt='d', cmap='Blues', cbar=False) 
        plt.xlabel('Previsto')
        plt.ylabel('Real')
        plt.title('Matriz de Confusão com MinMax')
        plt.show()
    return

X_train = pd.read_csv("../datasets/df_X_train_imput_knn.csv")
X_test = pd.read_csv("../datasets/df_X_test_imput_knn.csv")
y_train = pd.read_csv("../datasets/df_y_train_imput_knn.csv")
y_test = pd.read_csv("../datasets/df_y_test_imput_knn.csv")

algoritmo_Knn(X_train, X_test, y_train, y_test, "knn")
# Out:
# c:\Users\zvito\anaconda3\envs\datascience\Lib\site-packages\sklearn\neighbors\_classification.py:243: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\zvito\anaconda3\envs\datascience\Lib\site-packages\sklearn\neighbors\_classification.py:243: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Acurácia Dados Brutos com imputação por knn, StandartScaler: 0.711 e 2 vizinho(s).
# Acurácia Dados Brutos com imputação por knn, MinMaxScaler: 0.699 e 2 vizinho(s).
# Acurácia Dados Brutos com imputação por knn, StandartScaler: 0.731 e 3 vizinho(s).
# c:\Users\zvito\anaconda3\envs\datascience\Lib\site-packages\sklearn\neighbors\_classification.py:243: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\zvito\anaconda3\envs\datascience\Lib\site-packages\sklearn\neighbors\_classification.py:243: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Acurácia Dados Brutos com imputação por knn, MinMaxScaler: 0.734 e 3 vizinho(s).
# Acurácia Dados Brutos com imputação por knn, StandartScaler: 0.725 e 4 vizinho(s).
# c:\Users\zvito\anaconda3\envs\datascience\Lib\site-packages\sklearn\neighbors\_classification.py:243: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\zvito\anaconda3\envs\datascience\Lib\site-packages\sklearn\neighbors\_classification.py:243: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Acurácia Dados Brutos com imputação por knn, MinMaxScaler: 0.710 e 4 vizinho(s).
# Acurácia Dados Brutos com imputação por knn, StandartScaler: 0.738 e 5 vizinho(s).
# c:\Users\zvito\anaconda3\envs\datascience\Lib\site-packages\sklearn\neighbors\_classification.py:243: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\zvito\anaconda3\envs\datascience\Lib\site-packages\sklearn\neighbors\_classification.py:243: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Acurácia Dados Brutos com imputação por knn, MinMaxScaler: 0.710 e 5 vizinho(s).
# Acurácia Dados Brutos com imputação por knn, StandartScaler: 0.733 e 6 vizinho(s).
# c:\Users\zvito\anaconda3\envs\datascience\Lib\site-packages\sklearn\neighbors\_classification.py:243: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\zvito\anaconda3\envs\datascience\Lib\site-packages\sklearn\neighbors\_classification.py:243: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Acurácia Dados Brutos com imputação por knn, MinMaxScaler: 0.705 e 6 vizinho(s).
# Acurácia Dados Brutos com imputação por knn, StandartScaler: 0.739 e 7 vizinho(s).
# c:\Users\zvito\anaconda3\envs\datascience\Lib\site-packages\sklearn\neighbors\_classification.py:243: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\zvito\anaconda3\envs\datascience\Lib\site-packages\sklearn\neighbors\_classification.py:243: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Acurácia Dados Brutos com imputação por knn, MinMaxScaler: 0.705 e 7 vizinho(s).
# Acurácia Dados Brutos com imputação por knn, StandartScaler: 0.723 e 8 vizinho(s).
# c:\Users\zvito\anaconda3\envs\datascience\Lib\site-packages\sklearn\neighbors\_classification.py:243: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\zvito\anaconda3\envs\datascience\Lib\site-packages\sklearn\neighbors\_classification.py:243: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Acurácia Dados Brutos com imputação por knn, MinMaxScaler: 0.688 e 8 vizinho(s).
# Acurácia Dados Brutos com imputação por knn, StandartScaler: 0.725 e 9 vizinho(s).
# c:\Users\zvito\anaconda3\envs\datascience\Lib\site-packages\sklearn\neighbors\_classification.py:243: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\zvito\anaconda3\envs\datascience\Lib\site-packages\sklearn\neighbors\_classification.py:243: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Acurácia Dados Brutos com imputação por knn, MinMaxScaler: 0.706 e 9 vizinho(s).
